# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# misc
import os
from tqdm import tqdm, tnrange, tqdm_notebook
from pathlib import Path
import re
import numpy as np
import matplotlib.pyplot as plt
import cv2
import sys
import scipy.ndimage
import math
import pandas as pd
#import PIL
from PIL import Image

# %%
# dicom and nii
import pydicom
from pydicom.data import get_testdata_files
from pydicom.filereader import read_dicomdir
import pydicom.pixel_data_handlers.gdcm_handler as gdcm_handler
## ! gdcm must be installed with conda install (conda install -c conda-forge gdcm)
pydicom.config.image_handlers = ['gdcm_handler']
import nibabel as nib

# %%
# fast.ai lib
from fastai.vision import *
from fastai.metrics import *
from fastai.callbacks import *

# %%
# multithreading
from multiprocessing import Pool

# %% [markdown]
# ## Define paths

# %%
path_str = '/home/ubuntu/sfr-challenge/lungs/dataset'
# path_str = '/Users/igorgarbuz/SoftDev/sfr-challenge/dataset'

# %%
path = Path(path_str)

# %%
path_seg = path/'seg_3d'

# %%
path_p = path/'Pathologiques'

# %%
path_n = path/'Normaux'

# %%
path_train = path/'train'
path_train_1 = path_train/'1'
path_train_0 = path_train/'0'
if not os.path.exists(path_train_1): os.makedirs(path_train_1)
if not os.path.exists(path_train_0): os.makedirs(path_train_0)

# %%
test_path = path_str + '/Pathologiques/N7Q0jai/N7Q0jai'

# %% [markdown]
# ## Define fixed random seed

# %%
np.random.seed(42)

# %% [markdown]
# ## Patients to exclude

# %%
exclude = {'1fmJ54h', '4PgdJEv', '93pFUjH', 'AoNf6az', 'H8cPI77', 'kalMNNP', 'mDb8hKS', 'SMwf6qh', 'V3Gli1y'}

# %%
exclude_nii3d = {'Seg_fhCY9du.nii.gz', 'Seg_cUXgmoh.nii.gz', 'Seg_G2YmH9u.nii.gz', 'Seg_gk033Ar.nii.gz', 'Seg_WI7IMWW.nii.gz', 'Seg_S2KbtNT.nii.gz', 'Seg_X5lwqWZ.nii.gz', 'Seg_cRJUBEy.nii.gz'}

# %% [markdown]
# ## Test section ==>

# %% [markdown]
# ## <== End of test section

# %% [markdown]
# ## Define file loaders

# %%
# debug sorting https://pydicom.github.io/pydicom/dev/auto_examples/image_processing/reslice.html
# order reversed must be based on patients orientation / origin from the metadata
# ImagePositionPatient is used to sort slides
def load_dicom(path):
    slices = [pydicom.dcmread(path + '/' + s) for s in os.listdir(path) if ".dcm" in s.lower()]
    try:
        slices.sort(key = lambda x: x.ImagePositionPatient[2], reverse=False)
    except:
        slices.sort(key = lambda x: x.InstanceNumber, reverse=True)
        print("No ImagePositionPatient[2] at:", path)
    return slices

# %%
#     except ValueError: can be used to 
def get_pixels_hu(slices, path):
    arr = np.array([], dtype=np.int16)
    # convert list of slices into ndarray
    try:
        arr = np.stack([s.pixel_array for s in slices])
    except:
        print('cannot stack at: ', path)
    arr = arr.astype(np.int16)
    # set outside-of-scann pixels to zero (200 by default)
    # see housfield units for more details https://en.wikipedia.org/wiki/Hounsfield_scale
    arr[arr == -2000] = 0
    # read Intercept and slope convert to Housfield units (HU)
    try:
        intercept = slices[0].RescaleIntercept
    except ValueError:
        print('cannot get intercept at: ', path)
    try:
        slope = slices[0].RescaleSlope
    except:
        print('cannot get slope at: ', path)
    if slope != 1:
        arr = slope * arr.astype(np.float64)
        arr = arr.astype(np.int16)
    arr += np.int16(intercept)
    return np.array(arr, dtype=np.int16)

# %% [markdown]
# ## Below section: create RGB image from 3D numpy array

# %%
def get_rgb_image(label, img_3d, stride=1):
    step = stride + 1
    slice_n_minus_1 = img_3d[label - step]
    slice_n = img_3d[label]
    slice_n_plus_1 = img_3d[label + step]
    img = np.array([slice_n_minus_1,\
                    slice_n,\
                    slice_n_plus_1])
    return np.moveaxis(img, 0, 2)

# %%
# normalize to [0; 65535]
# alternative normalization functions are in the "Test" section
# use second image normalize line for 8 bit images
MIN = -1000.0
MAX = 400.0
def normalize_cv2(image):
    image[image > MAX] = MAX
    image[image < MIN] = MIN
    #image = cv2.normalize(image, dst=None, alpha=0, beta=65535, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_16U)
    image = cv2.normalize(image, dst=None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    return image

# %%
def resize(img, slc, new_spacing=[0.75, 0.75]):
    init_spacing = [slc.PixelSpacing[0], slc.PixelSpacing[1]]
    spacing = map(float, init_spacing)
    spacing = np.array(list(spacing))
    
    resize_factor = spacing / new_spacing
    new_shape_float = img.shape[:2] * resize_factor
    new_shape = np.round(new_shape_float)
    
    resize_factor_real = new_shape / img.shape[:2]
    new_spacing = spacing / resize_factor_real
    img = cv2.resize(img, None, fx=resize_factor_real[0], fy=resize_factor_real[1])
    return img, resize_factor_real

# %%
def crop_center(img_nda, new_width=256, new_height=256):
    shape = img_nda.shape
    width = shape[0]
    height = shape[1]
    left = round((width - new_width) / 2)
    top = round((height - new_height) / 2)
    right = round((width + new_width) / 2)
    bottom = round((height + new_height) / 2)
    if (left > 0 and right > left and top > 0 and bottom > top): 
        crop_img = img_nda[top:bottom, left:right]
    else:
        crop_img = img_nda
    return (crop_img)

# %%
def split_quart(img, patient, qt_width=224, qt_height=224, pad_w=5, pad_h=5):
    shape = img.shape
    width = shape[0]
    height = shape[1]
    center_w = round(width / 2)
    center_h = round(height / 2)
    if center_h + pad_h - qt_height <= 0 or center_w + pad_w - qt_width <= 0:
        pad_w = qt_width - center_w
        pad_h = qt_height - center_h
        print('split_quart: image: ', patient, ' too small: ', shape)
    qt_upl = img[center_h + pad_h - qt_height : center_h + pad_h, center_w + pad_w - qt_width : center_w + pad_w]
    qt_upr = img[center_h + pad_h - qt_height : center_h + pad_h, center_w - pad_w : center_w - pad_w + qt_width]
    qt_dwl = img[center_h - pad_h : center_h - pad_h + qt_height, center_w + pad_w - qt_width : center_w + pad_w]
    qt_dwr = img[center_h - pad_h : center_h - pad_h + qt_height, center_w - pad_w : center_w - pad_w + qt_width]
    return qt_upl, qt_upr, qt_dwl, qt_dwr

# %%
def get_image_from_seg(label_slice):
    label_img = cv2.normalize(label_slice, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    # orient = _slice.ImageOrientationPatient - original patient orientation data
    label_img = np.rot90(label_img)
    label_img = np.flipud(label_img)
    return (label_img)

# %% [markdown]
# ## Below section : functions to get slices from nii

# %%
# function count sequences of unique numbers and returns a list of sequences' length
# [0] corresponds to no sequences, [1] - sequence of length 1, [3,4] - two sequences of length 3 and 4
def get_unique_nodules(uniques_z):
    labels = []
    i = 1
    if len(uniques_z) == 0: return [0]
    elif len(uniques_z) == 1: return [i]
    prev = uniques_z[0]
    for s in uniques_z[1:]:
        if s == prev + 1:
            prev = s
            i += 1
        else:
            labels += [i]
            i = 1
            prev = s
        if s == uniques_z[-1]:
            labels += [i]
            return np.array(labels)

# %%
# target depth is a target thickness in mm of the rgb x3 layers stack;
# It is basically the distance between exterior layers R and B
def get_stride(_slice):
    s = _slice.SliceThickness
    #print('SliceThickness:', s)
    if s >= 2 and s <= 3: stride = 0
    elif s > 0.9 and s <= 2: stride = 1
    elif s > 0.6 and s <= 0.9: stride = 2
    elif s > 0.5 and s <= 0.6: stride = 3
    else:
        print('SliceThickness is: ', s, ' at: ', _slice.PatientName)
        stride = 3
        print('stride out of range')
    #print('stride: ', stride)
    return int(stride)

# %%
# returns an array with indexes of z slices containing labels
# step in mm [+- 0.25]; min_sz in mm [+- 1]
def get_z_slices(nii_path, stride=1):
    step = 1 + stride
    pad = 1
    min_sz = 3 + 2 * stride + 2 * pad
    # below try to replace by path_patholog = path_p
    path_patholog='/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques'
    slices = []
    raw_pixels = nib.load(nii_path).get_fdata() 
    labels_3d = raw_pixels.nonzero()
    uniques_z = np.unique(labels_3d[2])
    nodules = get_unique_nodules(uniques_z)
    for nod in nodules:
        if nod >= min_sz:
            slc = slice(step + pad, nod - pad - step, step)
            slices += list(uniques_z[slc])
        else:
            slices += [uniques_z[int(nod/2)]]
        uniques_z = uniques_z[nod:]
    return slices, raw_pixels

# %% [markdown]
# ## Create list of patients from .nii segmentations

# %%
patients_segs = [str(path_seg) + '/' + p for p in os.listdir(path_seg) if p not in exclude_nii3d]

# %% [markdown]
# ## Generator method 1 : Read .dcm, get slices from .nii, save .tif and label .jpg

# %%
def check_label(img):
    nonz = img.nonzero()
    unq = np.unique(nonz)
    return len(unq)

# %%
# generate .tif + .jpg for ORIGINAL patient's 3D
# it whold iterate over a list of patients' segmentations .nii.gz
def generate_training_set(patient_seg):
    # get patient name and directory
    pat = "(Seg\w*_)(\w+)"
    patient = re.search(pat, patient_seg)[2]
    patient_dir = path_p/patient/patient 
    
    #load patient 3D data
    slices = load_dicom(str(patient_dir))
    img_3d = get_pixels_hu(slices, patient_dir)
    stride = get_stride(slices[0])
    
    # get slices to extract
    slices_nii, raw_pxl_nii = get_z_slices(patient_seg, stride=stride)
    for s in slices_nii:
        img_rgb = normalize_cv2(get_rgb_image(s, img_3d, stride=stride))
        #img_rgb, scale = resize(img_rgb, slices[0], new_spacing=[0.76, 0.76])
        img_rgb, scale = resize(img_rgb, slices[0], new_spacing=[1.1, 1.1])
        img_seg = get_image_from_seg(raw_pxl_nii[:,:,s])
        img_seg = cv2.resize(img_seg, None, fx=scale[0], fy=scale[1])
        img_seg = crop_center(img_seg)
        # Generate whole-slide picture
        img_rgb = crop_center(img_rgb)
        cv2.imwrite(str(path_train) + '/1/' + patient + '_' + str(s) + '.tif', img_rgb)
        cv2.imwrite(str(path_train) + '/1/' + patient + '_' + str(s) + '.jpg', img_seg)
    return patient_dir

# %%
for p in tqdm_notebook(patients_segs[:10]):
    generate_training_set(p)

# %%
prc = Pool(4)
# Out:
# start:  /home/ubuntu/sfr-challenge/lungs/dataset/seg_3d/Seg
),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/ozDdqkE/ozDdqkE'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/ztmIQaQ/ztmIQaQ'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/6PXNYso/6PXNYso'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/aFfujKS/aFfujKS'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/O6esDhA/O6esDhA'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/7dDY4Nw/7dDY4Nw'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/hLfvKwl/hLfvKwl'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/mKVODHl/mKVODHl'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/EFzVyzy/EFzVyzy'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/HREchk8/HREchk8'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/L7Vpfjb/L7Vpfjb'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/1U6QptJ/1U6QptJ'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/N7Q0jai/N7Q0jai'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/wYnsIcD/wYnsIcD'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/alZm46B/alZm46B'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/QW0x3Et/QW0x3Et'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/w0vrbn9/w0vrbn9'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/FOzMVBB/FOzMVBB'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/TQKQvty/TQKQvty'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/Xqp9fjq/Xqp9fjq'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/ozRawV0/ozRawV0'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/wH3nrUv/wH3nrUv'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/yssUbcX/yssUbcX'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/qeg0acT/qeg0acT'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/N5wHSr9/N5wHSr9'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/LkBuNI7/LkBuNI7'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/RYb5h1y/RYb5h1y'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/SpsytzY/SpsytzY'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/ERet3GA/ERet3GA'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/dk5Ob4j/dk5Ob4j'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/vnn92kc/vnn92kc'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/GqPnN5b/GqPnN5b'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/64jet6a/64jet6a'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/ccGwZdT/ccGwZdT'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/B9JMPgg/B9JMPgg'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/CdLzD0p/CdLzD0p'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/6cilmpQ/6cilmpQ'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/99Y8w5i/99Y8w5i'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/6pjUXBe/6pjUXBe'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/c85J9jh/c85J9jh'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/2k55L8P/2k55L8P'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/D4XRvSw/D4XRvSw'),
#  PosixPath('/home/ubuntu/sfr-challenge/lungs/dataset/Pathologiques/pnrhncu/pnrhncu')]

# %% [markdown]
# ### Analyze generated images

# %%
imgs_ds = os.listdir(path_train_1)
imgs_ds.sort()

# %%
plt.hist(res, bins=10)

# %% [markdown]
# ## Loop through Normaux patients folders and create train dataset

# %%
def get_rand_slices_idx(img_3d, stride=1, pics_n=10):
    step = stride + 1
    pad = step * 5
    low_idx = step + pad + 1
    high_idx = img_3d.shape[0] - step - 1 - pad
    rand_idx = np.random.randint(low=low_idx, high=high_idx, size=pics_n)
    return(rand_idx)

# %%
def generate_training_set_from_norm(patient):
    print('started: ', patient)
    # get 3D image
    slices = load_dicom(str(path_n/patient))
    img_3d = get_pixels_hu(slices, path_p/patient)
    stride = get_stride(slices[0])
    # get slices to extract
    random_slices_idx = get_rand_slices_idx(img_3d, pics_n=17)
    for s in random_slices_idx:
        img_rgb = normalize_cv2(get_rgb_image(s, img_3d, stride=stride))
        img_rgb, scale = resize(img_rgb, slices[0], new_spacing=[1.1, 1.1])
        img_rgb = crop_center(img_rgb)
        cv2.imwrite(str(path_train) + '/0/' + patient + '_' + str(s) + '.tif', img_rgb)
    print('finished: ', patient)
    return patient

# %% [markdown]
# ### Generate list of patients

# %%
pats_norm = os.listdir(path_n)
len(pats_norm)
# Out:
# 345

# %%
for p in tqdm_notebook(pats_norm[:50]):
    generate_training_set_from_norm(p)

# %%
proc = Pool(4)
# Out:
# started:  jLKrkWO
# started:  0L2mt7E
# started:  bU8K5D1
# started:  CHRE
# finished:  CHRE
# started:  k6GmW4k
# finished:  bU8K5D1
# started:  P14YqgJ
# finished:  0L2mt7E
# started:  dRIjnzq
# finished:  k6GmW4k
# started:  Byo4nG7
# finished:  jLKrkWO
# started:  tWT9t9c
# finished:  P14YqgJ
# started:  RVkgSTh
# finished:  Byo4nG7
# started:  yFnM4cV
# finished:  dRIjnzq
# started:  qa8bfmZ
# finished:  RVkgSTh
# started:  ZpIeYZj
# finished:  yFnM4cV
# started:  qRFr2ep
# finished:  qa8bfmZ
# started:  HA3GCPH
# finished:  ZpIeYZj
# started:  ypACSsB
# finished:  ypACSsB
# started:  gGj2s7u
# finished:  HA3GCPH
# started:  yrkau4M
# finished:  tWT9t9c
# started:  EP3d1dK
# finished:  gGj2s7u
# started:  T308psJ
# finished:  yrkau4M
# started:  lkq3IJ0
# finished:  EP3d1dK
# started:  VjN6duO
# finished:  T308psJ
# started:  rtsTEYp
# finished:  lkq3IJ0
# started:  iO8yoGR
# finished:  VjN6duO
# started:  PBx54GA
# finished:  qRFr2ep
# started:  dyPaCMp
# finished:  iO8yoGR
# started:  TFj38B4
# finished:  rtsTEYp
# started:  SMDlKGe
# finished:  dyPaCMp
# started:  r3rdKbn
# finished:  TFj38B4
# started:  oOLyTG5
# finished:  SMDlKGe
# started:  oWJfm6o
# finished:  r3rdKbn
# started:  IlwzGS1
# finished:  oWJfm6o
# started:  PXIWWSr
# finished:  IlwzGS1
# started:  XvDykCC
# finished:  PXIWWSr
# started:  4mqxCcQ
# finished:  PBx54GA
# started:  JBhGRIu
# finished:  XvDykCC
# started:  DjFF2mV
# finished:  4mqxCcQ
# started:  fBsljHW
# finished:  JBhGRIu
# started:  akrQ1Ms
# finished:  DjFF2mV
# started:  8zotgWC
# finished:  fBsljHW
# started:  OPT_
# finished:  oOLyTG5
# started:  5ufH2fy
# finished:  8zotgWC
# started:  GsMFQFA
# finished:  akrQ1Ms
# started:  cUU39yf
# finished:  5ufH2fy
# started:  IBylZrm
# finished:  cUU39yf
# started:  EG7nSmW
# finished:  GsMFQFA
# started:  mHyTL9J
# finished:  EG7nSmW
# started:  9m1A1Bd
# finished:  IBylZrm
# started:  A8cfYAg
# finished:  OPT_
# started:  KlAW8oN
# finished:  KlAW8oN
# started:  Cvy1b15
# finished:  9m1A1Bd
# started:  JN6KDJL
# finished:  mHyTL9J
# started:  N338fqS
# finished:  A8cfYAg
# started:  ToeNaft
# finished:  Cvy1b15
# started:  p64ICrp
# finished:  JN6KDJL
# started:  IwYYQy8
# finished:  N338fqS
# started:  84x7SrL
# finished:  ToeNaft
# started:  BLX5RkJ
# finished:  IwYYQy8
# started:  AlGRbCe
# finished:  84x7SrL
# started:  2hxpoSO
# finished:  BLX5RkJ
# started:  KveJCZB
# finished:  AlGRbCe
# started:  a6nvfdp
# finished:  KveJCZB
# started:  siIhuK0
# finished:  siIhuK0
# started:  NvPnrGS
# finished:  a6nvfdp
# started:  FQvqT3b
# finished:  p64ICrp
# started:  nmToeFp
# finished:  NvPnrGS
# started:  5boVDPi
# finished:  FQvqT3b
# started:  gMOf2Ug
# finished:  5boVDPi
# started:  LUDtN51
# finished:  2hxpoSO
# started:  GAG
# finished:  nmToeFp
# started:  Dzi65my
# finished:  GAG
# started:  lDfODZB
# finished:  gMOf2Ug
# started:  JKKzVcG
# finished:  LUDtN51
# started:  a7YzZVx
# finished:  Dzi65my
# started:  Sd7fZKN
# finished:  lDfODZB
# started:  SjRQNxW
# finished:  JKKzVcG
# started:  SOEMoQ9
# finished:  a7YzZVx
# started:  AeIkyAp
# finished:  SjRQNxW
# started:  P5ivXta
# finished:  Sd7fZKN
# started:  mAbDJAe
# finished:  AeIkyAp
# finished:  mAbDJAe
# started:  u738iXG
# started:  oDBGFXu
# finished:  P5ivXta
# started:  dSDZL31
# finished:  u738iXG
# started:  PfvNmUP
# finished:  oDBGFXu
# started:  9zK5jiJ
# finished:  9zK5jiJ
# started:  6iaIBnl
# finished:  PfvNmUP
# started:  pasBUpM
# finished:  6iaIBnl
# started:  BcQKftd
# finished:  SOEMoQ9
# started:  eoNleXS
# finished:  pasBUpM
# started:  NVwVccn
# finished:  eoNleXS
# started:  JrERPL5
# finished:  NVwVccn
# started:  4emgVVd
# finished:  JrERPL5
# started:  nnKcsM4
# finished:  nnKcsM4
# started:  Z6qQl1j
# finished:  dSDZL31
# started:  Akk4uID
# finished:  BcQKftd
# started:  LA60nLX
# finished:  Z6qQl1j
# started:  crPOslv
# finished:  LA60nLX
# started:  QBUxh2s
# finished:  Akk4uID
# started:  rl6hYeg
# finished:  crPOslv
# started:  rOFfLTQ
# finished:  rl6hYeg
# started:  UHfu9oS
# finished:  4emgVVd
# started:  bfIqvbI
# finished:  QBUxh2s
# started:  xxE6GDq
# finished:  rOFfLTQ
# started:  e04KQgA
# finished:  UHfu9oS
# started:  Id87krI
# finished:  e04KQgA
# started:  xm4nLJ9
# finished:  xxE6GDq
# started:  8nnlkLr
# finished:  xm4nLJ9
# started:  5vnbtyg
# finished:  8nnlkLr
# started:  oN7Vm7z
# finished:  5vnbtyg
# started:  LLx94S9
# finished:  oN7Vm7z
# started:  78DGbLo
# finished:  LLx94S9
# started:  fDELKZH
# finished:  Id87krI
# started:  UMo9UD3
# finished:  78DGbLo
# started:  j50ZYt1
# finished:  bfIqvbI
# started:  ekh4jRj
# finished:  UMo9UD3
# started:  5J4TlJY
# finished:  j50ZYt1
# started:  b9W5Ebe
# finished:  fDELKZH
# finished:  ekh4jRj
# started:  GcYyUcc
# started:  KjzUG0j
# finished:  5J4TlJY
# started:  v5do888
# finished:  GcYyUcc
# started:  JW2QQiM
# finished:  v5do888
# started:  EAR9C5N
# finished:  b9W5Ebe
# started:  KXRLDpB
# finished:  JW2QQiM
# started:  oiVZzS4
# finished:  EAR9C5N
# started:  Alkyd76
# finished:  KXRLDpB
# started:  rrcCIp5
# finished:  oiVZzS4
# started:  l1qRKBu
# finished:  rrcCIp5
# started:  sn7s33U
# finished:  Alkyd76
# started:  RBGOnEk
# finished:  l1qRKBu
# started:  1wEO9q9
# finished:  sn7s33U
# started:  ydF84IE
# finished:  KjzUG0j
# started:  CO2vpyf
# finished:  1wEO9q9
# started:  gutpUgd
# finished:  RBGOnEk
# started:  YHdNwcs
# finished:  gutpUgd
# started:  elBN24Y
# finished:  CO2vpyf
# started:  faf5UHN
# finished:  ydF84IE
# started:  5eonYkS
# finished:  YHdNwcs
# started:  p6HZKlL
# finished:  elBN24Y
# started:  aftJmch
# finished:  faf5UHN
# started:  OpiQI4R
# finished:  5eonYkS
# started:  Y2ed5T2
# finished:  aftJmch
# started:  YU2h1W2
# finished:  p6HZKlL
# started:  HORM_
# finished:  OpiQI4R
# started:  P6xGZu6
# finished:  Y2ed5T2
# finished:  HORM_
# started:  3bQ5MT8
# finished:  YU2h1W2
# started:  5VILBp4
# started:  i62wc9J
# finished:  P6xGZu6
# started:  zSi4JIK
# finished:  5VILBp4
# started:  pcIcePr
# finished:  i62wc9J
# started:  7XFTXm0
# finished:  zSi4JIK
# started:  Q9CLsbx
# finished:  pcIcePr
# started:  pD2Rj2b
# finished:  Q9CLsbx
# started:  oCpZpOV
# finished:  7XFTXm0
# started:  lu4Qj1k
# finished:  pD2Rj2b
# started:  BRv41LC
# finished:  oCpZpOV
# started:  fX4nenh
# finished:  lu4Qj1k
# started:  JYVMM5v
# finished:  BRv41LC
# started:  dqqcWG0
# finished:  fX4nenh
# started:  NGO_
# finished:  dqqcWG0
# started:  SUGAqZm
# finished:  JYVMM5v
# started:  VNl4oQU
# finished:  NGO_
# started:  2BcjlRY
# finished:  3bQ5MT8
# started:  oxzyjEM
# finished:  2BcjlRY
# started:  DDjnlXM
# finished:  VNl4oQU
# started:  dOjwXyn
# finished:  SUGAqZm
# started:  qHZiBFk
# finished:  oxzyjEM
# started:  V7l3Skz
# finished:  DDjnlXM
# started:  ywkfMQS
# finished:  dOjwXyn
# started:  DJyQNxu
# finished:  V7l3Skz
# started:  2Vx3kRp
# finished:  qHZiBFk
# started:  ymRPQvA
# finished:  2Vx3kRp
# started:  KqfHdLP
# finished:  ywkfMQS
# started:  M1HomrE
# finished:  DJyQNxu
# started:  gah3kfM
# finished:  ymRPQvA
# started:  670QI3P
# finished:  KqfHdLP
# started:  BLI
# finished:  670QI3P
# started:  LUIu9Xy
# finished:  gah3kfM
# started:  NzZ0kZf
# finished:  BLI
# started:  m1o0SjQ
# finished:  m1o0SjQ
# started:  tjwSYrf
# finished:  LUIu9Xy
# started:  cazvOFk
# finished:  tjwSYrf
# started:  rtlMfdX
# finished:  rtlMfdX
# started:  LmHufe5
# finished:  cazvOFk
# started:  GxVmcAE
# finished:  M1HomrE
# started:  vRvbOgH
# finished:  vRvbOgH
# started:  CHlFlGh
# finished:  NzZ0kZf
# started:  hyZ1E4V
# finished:  CHlFlGh
# started:  2vOSuE0
# finished:  LmHufe5
# started:  udWTrZt
# finished:  GxVmcAE
# started:  BT584po
# finished:  hyZ1E4V
# started:  f9lLiwa
# finished:  BT584po
# started:  uCGOHj3
# finished:  f9lLiwa
# started:  5scLC9o
# finished:  udWTrZt
# started:  CIS
# finished:  5scLC9o
# finished:  uCGOHj3
# started:  GTDiUnz
# started:  tSxrFit
# finished:  CIS
# started:  iBVEQae
# finished:  tSxrFit
# started:  gIo2EPk
# finished:  2vOSuE0
# started:  FOU
# finished:  iBVEQae
# started:  SIqjY2r
# finished:  gIo2EPk
# started:  cI2P4if
# finished:  FOU
# started:  3chH7AP
# finished:  SIqjY2r
# started:  qRrcCVO
# finished:  cI2P4if
# started:  SbaBpgT
# finished:  qRrcCVO
# started:  NVEpW3x
# finished:  SbaBpgT
# started:  NyT8Azl
# finished:  GTDiUnz
# started:  11pyhVV
# finished:  NyT8Azl
# started:  0qPvA0p
# finished:  0qPvA0p
# started:  RuwFGK5
# finished:  3chH7AP
# started:  6wj2DEs
# finished:  RuwFGK5
# started:  sA9Cnmd
# finished:  11pyhVV
# started:  CIUC
# finished:  sA9Cnmd
# started:  G4SMLHv
# finished:  NVEpW3x
# finished:  CIUC
# started:  GNWdOvq
# started:  EmtHxXi
# finished:  G4SMLHv
# started:  VuxYT31
# finished:  EmtHxXi
# started:  kL4icM8
# finished:  GNWdOvq
# started:  4e8fSkF
# finished:  VuxYT31
# started:  MAS_
# finished:  kL4icM8
# started:  C71qOU1
# finished:  6wj2DEs
# started:  HgFg6SF
# finished:  4e8fSkF
# started:  jxqzOQH
# finished:  HgFg6SF
# started:  FLrsK4v
# finished:  C71qOU1
# started:  cLucmlX
# finished:  jxqzOQH
# started:  gQrRrnO
# finished:  FLrsK4v
# started:  AnyK8ix
# finished:  gQrRrnO
# finished:  cLucmlX
# started:  E0TGtvo
# started:  T4OICET
# finished:  MAS_
# started:  RXydGpB
# finished:  RXydGpB
# started:  MILO_
# finished:  T4OICET
# started:  tptcZ3a
# finished:  E0TGtvo
# started:  sKtPMew
# finished:  sKtPMew
# started:  Vu54vFr
# finished:  MILO_
# started:  hUyX3g9
# finished:  hUyX3g9
# started:  lLSY6CY
# finished:  AnyK8ix
# started:  wdTvE5V
# finished:  lLSY6CY
# started:  WR5ac2q
# finished:  wdTvE5V
# started:  l6EAvDE
# finished:  WR5ac2q
# started:  oMgQXgj
# finished:  tptcZ3a
# started:  wJcgHMB
# finished:  l6EAvDE
# started:  JSvcCFR
# finished:  Vu54vFr
# started:  4BbsuxC
# finished:  wJcgHMB
# started:  dfJnj8P
# finished:  JSvcCFR
# started:  a8QmsRG
# finished:  oMgQXgj
# started:  MAH_
# finished:  a8QmsRG
# started:  nfnhn7k
# finished:  dfJnj8P
# started:  EhyAazM
# finished:  4BbsuxC
# started:  KEDD_
# finished:  MAH_
# started:  cpDGFVA
# finished:  nfnhn7k
# started:  97U6ngS
# finished:  EhyAazM
# started:  ipORNqu
# finished:  KEDD_
# started:  11YNVGp
# finished:  97U6ngS
# started:  GZ4yVA8
# finished:  11YNVGp
# started:  wTXRmzh
# finished:  cpDGFVA
# started:  ut04yJT
# finished:  ipORNqu
# started:  LgnQWmU
# finished:  GZ4yVA8
# started:  RQLpXbY
# finished:  wTXRmzh
# started:  26CuXS5
# finished:  LgnQWmU
# started:  Bmt9dBu
# finished:  ut04yJT
# started:  Q03KwNF
# finished:  26CuXS5
# started:  4YJwVtQ
# finished:  Bmt9dBu
# started:  OZGD4eQ
# finished:  RQLpXbY
# started:  JojwkqL
# finished:  Q03KwNF
# started:  vXTxZ0H
# finished:  4YJwVtQ
# started:  3ii6Oqr
# finished:  JojwkqL
# started:  VU7NJ3N
# finished:  OZGD4eQ
# started:  YcH2P0f
# finished:  vXTxZ0H
# started:  aEkWaig
# finished:  VU7NJ3N
# started:  BENT
# finished:  aEkWaig
# started:  lkR95qr
# finished:  YcH2P0f
# started:  Gp2YDyR
# finished:  BENT
# started:  7JdnQHP
# finished:  lkR95qr
# started:  g8SwEAz
# finished:  Gp2YDyR
# started:  h1PHe6v
# finished:  7JdnQHP
# started:  E9ihj3O
# finished:  g8SwEAz
# started:  R17hLMp
# finished:  E9ihj3O
# started:  wmcABIZ
# finished:  3ii6Oqr
# started:  mMeV95Z
# finished:  h1PHe6v
# started:  yBHuO5i
# finished:  R17hLMp
# started:  m0BOwlz
# finished:  wmcABIZ
# started:  IO2YKeN
# finished:  yBHuO5i
# started:  bnVjL1G
# finished:  IO2YKeN
# started:  IeJwe6c
# finished:  m0BOwlz
# started:  3JCA3Qn
# finished:  IeJwe6c
# started:  YW0x4zY
# finished:  YW0x4zY
# started:  cHTvDze
# finished:  3JCA3Qn
# started:  DEMI
# finished:  mMeV95Z
# started:  sEEzPj7
# finished:  DEMI
# started:  BGlavAD
# finished:  cHTvDze
# started:  VutfOgE
# finished:  bnVjL1G
# started:  AgssXUh
# finished:  VutfOgE
# started:  cgGctQM
# finished:  sEEzPj7
# started:  kqS7MFi
# finished:  BGlavAD
# started:  63GAgG4
# finished:  AgssXUh
# started:  NmX8jca
# finished:  kqS7MFi
# started:  4A5xTid
# finished:  cgGctQM
# finished:  63GAgG4
# started:  2LNc6rG
# started:  Y1Uq9pf
# finished:  NmX8jca
# started:  XlQQyHa
# finished:  Y1Uq9pf
# started:  yoX7Ydd
# finished:  4A5xTid
# started:  NrcCPFC
# finished:  2LNc6rG
# started:  qBiMC5g
# finished:  yoX7Ydd
# started:  MPa6h95
# finished:  NrcCPFC
# started:  QUzEPhn
# finished:  MPa6h95
# started:  q7I64vP
# finished:  QUzEPhn
# started:  bRfWg6f
# finished:  XlQQyHa
# started:  bmaltLM
# finished:  q7I64vP
# started:  D3cMjuf
# finished:  bmaltLM
# started:  gLsPHnc
# finished:  D3cMjuf
# started:  A0l8e8f
# finished:  A0l8e8f
# started:  EcBeKPC
# finished:  qBiMC5g
# started:  7iXfEwV
# finished:  gLsPHnc
# started:  89kaUIR
# finished:  EcBeKPC
# started:  LFxSLjF
# finished:  7iXfEwV
# started:  OrQu6kT
# finished:  bRfWg6f
# started:  xEAXSV1
# finished:  LFxSLjF
# started:  laXvIss
# finished:  xEAXSV1
# started:  dJNfjnw
# finished:  OrQu6kT
# started:  YRrf4BV
# finished:  dJNfjnw
# started:  rmlxD5K
# finished:  YRrf4BV
# started:  0OH0u4G
# finished:  89kaUIR
# started:  okaAaVD
# finished:  rmlxD5K
# started:  HAM_
# finished:  0OH0u4G
# started:  O5E794H
# finished:  HAM_
# started:  wT6tqqR
# finished:  O5E794H
# started:  jjRsAMy
# finished:  okaAaVD
# started:  WFkKyW8
# finished:  laXvIss
# started:  eAqSfP2
# finished:  WFkKyW8
# started:  ZUKDZnt
# finished:  jjRsAMy
# started:  GZY1Esq
# finished:  ZUKDZnt
# started:  DogZQab
# finished:  GZY1Esq
# finished:  DogZQab
# started:  JFBbW5P
# finished:  wT6tqqR
# started:  tF1L1o7
# finished:  JFBbW5P
# started:  3ujVzWG
# finished:  tF1L1o7
# started:  X0FiM1X
# finished:  eAqSfP2
# finished:  3ujVzWG
# started:  j4KmSTf
# finished:  j4KmSTf
# started:  Pz37siI
# finished:  X0FiM1X
# started:  gurIdpS
# finished:  Pz37siI
# started:  Vg8erly
# finished:  Vg8erly
# started:  6XujrhL
# finished:  gurIdpS
# started:  bvzBW4A
# finished:  6XujrhL
# started:  IOwz3tZ
# finished:  bvzBW4A
# started:  kes2Vdj
# finished:  IOwz3tZ
# finished:  kes2Vdj
# started:  uGkc4Ls
# finished:  uGkc4Ls
# started:  hALh7G7
# finished:  hALh7G7

# %%
# %%time
# total time 10 min for 345 patients
proc.map(generate_training_set_from_norm, pats_norm)
# Out:
# CPU times: user 1.11 s, sys: 775 ms, total: 1.88 s
# Wall time: 8min 46s
# ['0L2mt7E',
#  'dRIjnzq',
#  'qa8bfmZ',
#  'HA3GCPH',
#  'yrkau4M',
#  'lkq3IJ0',
#  'iO8yoGR',
#  'TFj38B4',
#  'oOLyTG5',
#  '5ufH2fy',
#  'IBylZrm',
#  'A8cfYAg',
#  'ToeNaft',
#  'BLX5RkJ',
#  'KveJCZB',
#  'siIhuK0',
#  'NvPnrGS',
#  '5boVDPi',
#  'LUDtN51',
#  'a7YzZVx',
#  'AeIkyAp',
#  'oDBGFXu',
#  'jLKrkWO',
#  'tWT9t9c',
#  'EP3d1dK',
#  'VjN6duO',
#  'PBx54GA',
#  'JBhGRIu',
#  'akrQ1Ms',
#  'cUU39yf',
#  'EG7nSmW',
#  '9m1A1Bd',
#  'JN6KDJL',
#  'IwYYQy8',
#  'AlGRbCe',
#  'a6nvfdp',
#  'FQvqT3b',
#  'gMOf2Ug',
#  'JKKzVcG',
#  'SOEMoQ9',
#  'eoNleXS',
#  'JrERPL5',
#  'nnKcsM4',
#  'Z6qQl1j',
#  'bU8K5D1',
#  'P14YqgJ',
#  'RVkgSTh',
#  'ZpIeYZj',
#  'ypACSsB',
#  'gGj2s7u',
#  'T308psJ',
#  'rtsTEYp',
#  'SMDlKGe',
#  'oWJfm6o',
#  'PXIWWSr',
#  '4mqxCcQ',
#  'fBsljHW',
#  'OPT_',
#  'KlAW8oN',
#  'Cvy1b15',
#  'p64ICrp',
#  'nmToeFp',
#  'Dzi65my',
#  'Sd7fZKN',
#  'mAbDJAe',
#  'u738iXG',
#  'CHRE',
#  'k6GmW4k',
#  'Byo4nG7',
#  'yFnM4cV',
#  'qRFr2ep',
#  'dyPaCMp',
#  'r3rdKbn',
#  'IlwzGS1',
#  'XvDykCC',
#  'DjFF2mV',
#  '8zotgWC',
#  'GsMFQFA',
#  'mHyTL9J',
#  'N338fqS',
#  '84x7SrL',
#  '2hxpoSO',
#  'GAG',
#  'lDfODZB',
#  'SjRQNxW',
#  'P5ivXta',
#  'dSDZL31',
#  'Akk4uID',
#  'PfvNmUP',
#  'pasBUpM',
#  'NVwVccn',
#  '4emgVVd',
#  'bfIqvbI',
#  'ekh4jRj',
#  'KjzUG0j',
#  'CO2vpyf',
#  'faf5UHN',
#  'OpiQI4R',
#  'P6xGZu6',
#  'zSi4JIK',
#  'Q9CLsbx',
#  'oCpZpOV',
#  'fX4nenh',
#  'NGO_',
#  '2BcjlRY',
#  'DDjnlXM',
#  'ywkfMQS',
#  'M1HomrE',
#  'vRvbOgH',
#  'CHlFlGh',
#  '9zK5jiJ',
#  '6iaIBnl',
#  'BcQKftd',
#  'LA60nLX',
#  'QBUxh2s',
#  'xxE6GDq',
#  '8nnlkLr',
#  'oN7Vm7z',
#  '78DGbLo',
#  'j50ZYt1',
#  'b9W5Ebe',
#  'KXRLDpB',
#  'rrcCIp5',
#  'sn7s33U',
#  'ydF84IE',
#  '5eonYkS',
#  'Y2ed5T2',
#  '3bQ5MT8',
#  'oxzyjEM',
#  'V7l3Skz',
#  '2Vx3kRp',
#  'KqfHdLP',
#  'crPOslv',
#  'rOFfLTQ',
#  'e04KQgA',
#  'xm4nLJ9',
#  '5vnbtyg',
#  'LLx94S9',
#  'fDELKZH',
#  'GcYyUcc',
#  'JW2QQiM',
#  'oiVZzS4',
#  'l1qRKBu',
#  '1wEO9q9',
#  'gutpUgd',
#  'elBN24Y',
#  'aftJmch',
#  'YU2h1W2',
#  'i62wc9J',
#  '7XFTXm0',
#  'lu4Qj1k',
#  'JYVMM5v',
#  'VNl4oQU',
#  'dOjwXyn',
#  'rl6hYeg',
#  'UHfu9oS',
#  'Id87krI',
#  'UMo9UD3',
#  '5J4TlJY',
#  'v5do888',
#  'EAR9C5N',
#  'Alkyd76',
#  'RBGOnEk',
#  'YHdNwcs',
#  'p6HZKlL',
#  'HORM_',
#  '5VILBp4',
#  'pcIcePr',
#  'pD2Rj2b',
#  'BRv41LC',
#  'dqqcWG0',
#  'SUGAqZm',
#  'qHZiBFk',
#  'ymRPQvA',
#  '670QI3P',
#  'LUIu9Xy',
#  'DJyQNxu',
#  'gah3kfM',
#  'NzZ0kZf',
#  'hyZ1E4V',
#  'f9lLiwa',
#  '5scLC9o',
#  'GTDiUnz',
#  '11pyhVV',
#  'CIUC',
#  'EmtHxXi',
#  'kL4icM8',
#  'C71qOU1',
#  'cLucmlX',
#  'T4OICET',
#  'tptcZ3a',
#  'wJcgHMB',
#  'dfJnj8P',
#  'EhyAazM',
#  'ipORNqu',
#  'LgnQWmU',
#  'Bmt9dBu',
#  'OZGD4eQ',
#  'BLI',
#  'm1o0SjQ',
#  'tjwSYrf',
#  'rtlMfdX',
#  'LmHufe5',
#  'udWTrZt',
#  'CIS',
#  'iBVEQae',
#  'SIqjY2r',
#  'qRrcCVO',
#  'NVEpW3x',
#  'GNWdOvq',
#  '4e8fSkF',
#  'jxqzOQH',
#  'gQrRrnO',
#  'E0TGtvo',
#  'sKtPMew',
#  'Vu54vFr',
#  '4BbsuxC',
#  'KEDD_',
#  '11YNVGp',
#  'wTXRmzh',
#  'cazvOFk',
#  'GxVmcAE',
#  'BT584po',
#  'uCGOHj3',
#  'tSxrFit',
#  'gIo2EPk',
#  'cI2P4if',
#  'SbaBpgT',
#  'NyT8Azl',
#  '0qPvA0p',
#  'RuwFGK5',
#  'sA9Cnmd',
#  'G4SMLHv',
#  'VuxYT31',
#  'MAS_',
#  'RXydGpB',
#  'MILO_',
#  'hUyX3g9',
#  'lLSY6CY',
#  'WR5ac2q',
#  'oMgQXgj',
#  'MAH_',
#  '2vOSuE0',
#  'FOU',
#  '3chH7AP',
#  '6wj2DEs',
#  'HgFg6SF',
#  'FLrsK4v',
#  'AnyK8ix',
#  'wdTvE5V',
#  'l6EAvDE',
#  'JSvcCFR',
#  'a8QmsRG',
#  'nfnhn7k',
#  '97U6ngS',
#  'GZ4yVA8',
#  'RQLpXbY',
#  'JojwkqL',
#  'VU7NJ3N',
#  'BENT',
#  '7JdnQHP',
#  'E9ihj3O',
#  'wmcABIZ',
#  'IO2YKeN',
#  'cpDGFVA',
#  'ut04yJT',
#  'Q03KwNF',
#  'vXTxZ0H',
#  'aEkWaig',
#  'lkR95qr',
#  'g8SwEAz',
#  'R17hLMp',
#  'm0BOwlz',
#  '3JCA3Qn',
#  'DEMI',
#  'BGlavAD',
#  '63GAgG4',
#  '2LNc6rG',
#  'qBiMC5g',
#  '7iXfEwV',
#  'OrQu6kT',
#  'YRrf4BV',
#  '0OH0u4G',
#  'O5E794H',
#  'jjRsAMy',
#  'GZY1Esq',
#  '26CuXS5',
#  '4YJwVtQ',
#  '3ii6Oqr',
#  'mMeV95Z',
#  'sEEzPj7',
#  'kqS7MFi',
#  '4A5xTid',
#  'NrcCPFC',
#  'QUzEPhn',
#  'bRfWg6f',
#  'xEAXSV1',
#  'dJNfjnw',
#  'rmlxD5K',
#  'HAM_',
#  'wT6tqqR',
#  'tF1L1o7',
#  'X0FiM1X',
#  'gurIdpS',
#  'bvzBW4A',
#  'kes2Vdj',
#  'uGkc4Ls',
#  'hALh7G7',
#  'YcH2P0f',
#  'Gp2YDyR',
#  'h1PHe6v',
#  'yBHuO5i',
#  'bnVjL1G',
#  'AgssXUh',
#  'NmX8jca',
#  'XlQQyHa',
#  'bmaltLM',
#  'gLsPHnc',
#  '89kaUIR',
#  'okaAaVD',
#  'WFkKyW8',
#  'ZUKDZnt',
#  'DogZQab',
#  'JFBbW5P',
#  '3ujVzWG',
#  'j4KmSTf',
#  'Pz37siI',
#  'Vg8erly',
#  '6XujrhL',
#  'IOwz3tZ',
#  'IeJwe6c',
#  'YW0x4zY',
#  'cHTvDze',
#  'VutfOgE',
#  'cgGctQM',
#  'Y1Uq9pf',
#  'yoX7Ydd',
#  'MPa6h95',
#  'q7I64vP',
#  'D3cMjuf',
#  'A0l8e8f',
#  'EcBeKPC',
#  'LFxSLjF',
#  'laXvIss',
#  'eAqSfP2']
